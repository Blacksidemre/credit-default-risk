# %% [markdown]
# # 4. Modeling (LightGBM)
# Final model burada eğitilir ve skorlanır.

# %%
import sys
sys.path.append('..')
from src.pipeline import train_lgbm_with_features
pipe_lgbm, auc_lgbm = train_lgbm_with_features(save=False)
auc_lgbm
# Out:
# [LightGBM] [Info] Number of positive: 5309, number of negative: 18691
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001533 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4043
# [LightGBM] [Info] Number of data points in the train set: 24000, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.221208 -> initscore=-1.258639
# [LightGBM] [Info] Start training from score -1.258639
# C:\Users\Emre\Downloads\credit-default-risk-main (1)\credit-default-risk-main\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 0.7718194969868913
