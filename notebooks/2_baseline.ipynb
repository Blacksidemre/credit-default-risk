# %% [markdown]
# # 2. Baseline Model
# Logistic Regression ile ilk referans skor elde edilir.

# %%
import sys
sys.path.append('..')
from src.pipeline import train_baseline
pipe_log, auc_log = train_baseline()
auc_log
# Out:
# 0.7176002338950804
