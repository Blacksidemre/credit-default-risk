# %% [markdown]
# # 5. Evaluation
# ROC-AUC ve karışıklık matrisi incelenir.

# %%
import json, pathlib
metrics_path = pathlib.Path('..') / 'docs' / 'metrics.json'
print(metrics_path.read_text())
# Out:
# {
#   "logistic": {
#     "roc_auc": 0.7176002338950804,
#     "accuracy": 0.8093333333333333,
#     "precision": 0.6871165644171779,
#     "recall": 0.2532027128862095
#   },
#   "lightgbm": {
#     "roc_auc": 0.7718194969868913,
#     "accuracy": 0.816,
#     "precision": 0.6533700137551581,
#     "recall": 0.3579502637528259
#   }
# }
