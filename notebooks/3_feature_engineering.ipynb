# %% [markdown]
# # 3. Feature Engineering
# Eklenen özellikler ve etkileri burada incelenir.

# %%
import sys
sys.path.append('..')
from src.data_prep import load_raw_data, add_features
df_raw = load_raw_data()
df_fe = add_features(df_raw)
df_fe.head()
